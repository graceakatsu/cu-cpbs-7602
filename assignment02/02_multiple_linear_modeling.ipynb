# %% [markdown]
# # 02: Multiple linear modeling
#
# **Author:** Grace Akatsu
#
# **Class:** CPBS 7602, Fall 2025
#
# ---
# ## Overview
# This notebook performs multiple linear modeling on GTEx data from notebook 01.
#
# ## Table of Contents
# *   [Import libraries](#import_libraries)
# *   [Set paths and seed](#set_paths)
# *   [Read in data](#read_data)

# %% [markdown]
# ## Import libraries <a class="anchor" id="import_libraries"></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Set paths and seed <a class="anchor" id="set_paths"></a>

# %%
DATA_FILE = "clean_data/gtex_blood_brain_top5000_variable_genes_standardized.csv"

# %%
np.random.seed(0)

# %% [markdown]
# ## Read in data <a class="anchor" id="read_data"></a>

# %%
data = pd.read_csv(
    DATA_FILE,
    index_col="SAMPID"
)

data.head()
